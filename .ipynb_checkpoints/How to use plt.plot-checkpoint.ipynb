# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40],label = 'dotted',color = 'r',ls=':')
plt.plot([40,30,20,10],label = 'dashed',color = 'g',ls='--')
plt.plot([15,20,25,5],'b.',label = 'marker')
plt.title('basic')
plt.legend(loc=5)
plt.show()
