# %% [markdown]
# # csv파일 불러오기

# %%
import csv
f = open('seoul(1904-).csv','r',encoding='cp949') #'r' 모드, encoding 방식 디폴트
data = csv.reader(f,delimiter=',')#delimiter , 디폴트
header  = next(data)
print(header)
print()
for row in data:
    print(row)
print(data)

f.close()
# Out:
# ['날짜', '지점', '평균기온(℃)', '최저기온(℃)', '최고기온(℃)']
#
# ...
# ...
# ...
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-6-b8c18337ded4> in <module>
#       6 print()
#       7
# ----> 8 while next(data) != 0:
#       9     print(data)
#      10
#
# StopIteration:
