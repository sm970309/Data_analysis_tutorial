# %%
# import matplotlib.pyplot as plt

plt.rc('font',family = "Malgun Gothic")
size = [223,132,442,290]
label = ["A형","B형","O형","AB형"]

#원으로 만들어주는 메소드
plt.axis('equal')

#비율 표시(autopct)
#
plt.pie(size,labels=label,autopct='%.1f%%',explode = (0,0,0.1,0))

plt.legend()
plt.show()
